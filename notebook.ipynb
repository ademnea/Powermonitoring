8 MB/s eta 0:00:01
#    ----------------- ---------------------- 7.0/16.2 MB 13.2 MB/s eta 0:00:01
#    ------------------- -------------------- 7.8/16.2 MB 13.6 MB/s eta 0:00:01
#    -------------------- ------------------- 8.3/16.2 MB 12.9 MB/s eta 0:00:01
#    --------------------- ------------------ 8.8/16.2 MB 13.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.4/16.2 MB 13.1 MB/s eta 0:00:01
#    ------------------------ --------------- 10.0/16.2 MB 13.3 MB/s eta 0:00:01
#    -------------------------- ------------- 10.7/16.2 MB 12.8 MB/s eta 0:00:01
#    ------------------------------ --------- 12.2/16.2 MB 13.1 MB/s eta 0:00:01
#    -------------------------------- ------- 13.2/16.2 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.0/16.2 MB 13.9 MB/s eta 0:00:01
#    ------------------------------------ --- 14.9/16.2 MB 14.2 MB/s eta 0:00:01
#    -------------------------------------- - 15.5/16.2 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  16.2/16.2 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 13.9 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp312-cp312-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.5 MB 6.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.7/2.5 MB 8.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.4/2.5 MB 11.4 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 13.3 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 13.3 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 13.3 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 13.3 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 6.0 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB ? eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    --------------------------------------  501.8/505.5 kB 15.9 MB/s eta 0:00:01
#    ---------------------------------------- 505.5/505.5 kB 6.3 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------  337.9/345.4 kB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 345.4/345.4 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.0 numpy-2.0.0 pandas-2.2.2 pillow-10.3.0 pyparsing-3.1.2 pytz-2024.1 tzdata-2024.1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv("C:/Users/mukiibirogers/data.csv") # initial test
df1 = pd.read_csv("C:/Users/mukiibirogers/data01.csv") # testing again
df2 = pd.read_csv("C:/Users/mukiibirogers/data02.csv") # running for 9 minutes
df3 = pd.read_csv("C:/Users/mukiibirogers/data03.csv") # with the current sesnor connected to nothing at its terminals

print(f"df0: {df0.shape}, df1: {df1.shape}, df2: {df2.shape}")
# Out:
# df0: (336, 2), df1: (182, 2), df2: (10585, 2)

# %%
df2.head()
# Out:
#                   time   voltage
# 0  1719683317500671000  1.126537
# 1  1719683317505016000  1.153930
# 2  1719683317509461000  1.116869
# 3  1719683317513771000  1.107201
# 4  1719683317565958000  1.103978

# %%
import matplotlib.pyplot as plt

mean_voltage = df2['voltage'].mean()
# Plotting
fig, ax = plt.subplots(figsize=(14, 6))
ax.plot(df2["time"], df2["voltage"], label='Voltage', color='blue', linestyle='-')
ax.axhline(y=df2['voltage'].mean(),color='red', linestyle='--', linewidth=1.5, label=f'Mean Voltage: {mean_voltage:.2f}' )
# Add labels and title
ax.set_xlabel('Time')
ax.set_ylabel('Voltage')
ax.set_title('Voltage Over Time')

# Enable grid
ax.grid(True)

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

def plot_voltage_over_time(df, time_col, voltage_col):
    """
    Plots voltage over time and adds a mean voltage line.

    Parameters:
    df (pandas.DataFrame): The DataFrame containing the data.
    time_col (str): The name of the time column.
    voltage_col (str): The name of the voltage column.
    """
    # Calculate the mean voltage
    mean_voltage = df[voltage_col].mean()
    

    # Plotting
    fig, ax = plt.subplots(figsize=(14, 6))
    ax.plot(df[time_col], df[voltage_col], label='Voltage', color='blue', linestyle='-')

    # Add labels and title
    ax.set_xlabel('Time')
    ax.set_ylabel('Voltage')
    ax.set_title('Voltage Over Time')

    # Add a horizontal line for the mean voltage
    ax.axhline(y=mean_voltage, color='red', linestyle='--', linewidth=1.5, label=f'Mean Voltage: {mean_voltage:.2f}')
    
    # Add a legend
    ax.legend()

    # Show the plot
    plt.show()


plot_voltage_over_time(df2, "time", "voltage")

# %%
plot_voltage_over_time(df3, 'time', 'voltage')
